# %% [markdown]
# # Part 1 Machine Learning - Introduction

# %% [markdown]
# ## 1.Machine learning
# - It is a technique which enables computers to learn automatically from past data example . YOutube
# - It is an approach to train the model
# - It is helpful to predict the future values
#
# ## 2 Is machine learning hard
# - No never
# - MAchine learning is very easy
# - It requires Imagination creativity and a visual mind
# - Key points is we should learn how to play with data applying logic on data
# - This material helps how to do all these things

# %% [markdown]
# ### Human leaning
# - We will learn from situations
# - We will learn from experience
# - We will use our experience to do next step
#
# ### Machine leaning
# - ML will learn from Data
# - Alg learnt about the Data
# - alg == Model
#
# ### Pre - Requisite to learning Machine learning
# 1. Python => Function , Class, object , Methods
# 2. Pandas => Create a DataFrame
# 3. ML algorithm => Pure python code

# %% [markdown]
# ## 3. Program
# - Program =>  Group of instructions
# - A program is a group of instructions to perform the task ; computer can execute these instructions to finish the task
# - This is very good approach for simple task
#
#
# ## 4. What is an algorithm.?
# - An algorithm is program which having group of instruction to perform a task
# - input + Logic  =  Output
# - Data + Program =  Result
#
# ## 5 What is machine learning algorithm.?
# - Machine Learning algirthm is an application
# - It learn knowledge (patterns) automatically from the data without being explicity programmed
#   1. Data + Result = Program(Model)
#
# # Normal algorithm
# - Normal algorithm is just like a program
# - Normla algorithm dont know how to do prediction
#
# # ML algorithm
# - Ml algorithm also just like a program(special)
# - Ml algorith learn from Data
# - Why learning is required => to do the prediction
#
# ## 6 Diff b/n machine learning algorithm and normal algorithm .?
# - Machine Learning algorithm learns knowledge (patterns) from the Data .
# - Normal algorithm cannot learn anything on its own.
#
# ## 7 Why Machine learning ?
# - Currently every company is generataing huge amount of the data
# - So the volume of data is increasingg on every day .
# - Machine learning algorithms can extract infomation from data
# - The major use cases of Machine learning
#   1. Creating models
#   2. Getting deep insights & etc
# - Machine learning is going to be the center points of all fields.
#
# ## Data => Total Data
# ## Infomation => Use fil things total Data
#
#
# ## Machine learning algorithm
# - Learn from Data
# - Use experience
# - Do prediction
#
# ## 8 Machine Learning definition by Tom Mitchell
# - Machine learning is the study of computer algorithms that allow computer programs to automatically imporve through experience.  by Tom Mitchell
#
# ## by Arthur samuel definition
# - Machine learning term was introduced by Aruthur Samuel in the year of 1959 and he defined in this way
# - Machine learning is
#   1. Enables a machine to learn automatically from data
#   2. Improve performance from experiences,
#   3. Predict things without being explicitly programmed
#
# ## by Daniel defination
# - Teaching to computers how to learn by using data and experience rather than by instructions
#
# # 9 Artificial inteelligence vs Machine Learning vs Deep Learning (very veryyy imp)
#
# ## 9.1 Machine learning
# - Machine learning is a part of artifical intelligence
# - Machine learning is a technique of understand the data , learn from data and then apply what they have learnt to take next decision
# - Examples
#   1. Amazon using machine learning to give better product choico recommendations to their costumers based on their prefernces
#   2. Netflix uses machine learning to give better suggestions to their users of the TV series or movie or shows that they would like to watch & many more
#
# # Machine learning
# - It worsk mostly with structured data
# - example  csv file
# - We do have 7 steps => manually
# # Deep learning
# - It worsk mostly with unstructed data
# - image audio video
# - Few steps are automate
#
# ## 9.2 Deep learing
# - Deep learning is actually a subset of machine learning.
# - The main difference between deep and machine learning is , machine learning models works better but the model still needs some guidance
# - If a machine learning model returns an inaccurate prediction then the programmer needs to fix that problem explicity
# - In the case of deep learning the model does it by itself
# - Example Automatic car driving system is a good example of deep learning
#
# ## 9.3 Artificial intelligence
# - Al is an ability of computer program to function like a human brain
# - Machine learning and deep learning are the subsets of AI
# - The MOTO of AI is to replicate a human brain the way a human brain thinks works and functions
# - Currently AI is not yet fully implemented but we are very close to establish that too
# - Example
#   1. Sophia the most advanced AI mode present today
#
# ## 10 is computer identiying pictures on image like cate/dog
# - Yes and it is really amazing task
# - If we giving lot of images to computer then computer can try to learn about the attributes to recognize images
# - This is called as machine learning
#   1. It is something like teaching to computer how to think like a human
#
# ## 11 is human identifying picture on image like cat/dog .?
# - Absolutely Yes right
# - During my childhood parents / teachers taught like how to recognize a cat/dog/tiger/lion/etc
# - So in real life if we see cat/dog/tiger/lion (sorry tiger / lion  i have seen in zoo but not directly ) there we can easy to recognize without much effort
# - So a human can take the decision based on experience
#
# ## 12 Human vs computer
# - Human take the decisions based on the experience
# - Computer can create models by using data
#
# ## 13 How a machine can take the decisions ?
# - First we need to understand human secision making process before understanding about how a computer takes the decision
#
# ## 14 Past couple of decades
# - From past two decades most of the companies are digitalized
#
# ## 15 human's follows this formula ...
# - All human used to follow some patterns or formulas to take the next best action
#   1. Remember
#   2. Formulate
#   3. Predict
#
# ## 16 Generally
# - We remember past situation that were similar
# - We formulate a general rule
# - We use this rule to predict what will happen if we take certain decision
# - Example
#    1. For supposed to answer for question like will it rain today ? Or not ', then we will follow one process to answer this question right
#    2. We may be right or wrong but at leart we are trying to make an accurate prediction
#
# ## 17 How do machines thinks .?
# - The goal is to make the computer think the way we think , namely , how we use the remember formulate - predict framework.
# - Here are the points what the computer can understand the points
#
#
# - steps
#   1. Remember
#      - Look at the given HUGE Data
#   2. Formulate
#      - Go through rules and formulas, and check which one fits for the data
#   3. Predict
#      - Use the rule to make predictions about future data
#
# ## 18 Real time examples
# - Gmail application
# - Banking loan application or credit card eligibilty & etc
#
# ## 19 Gmail Application
# - Gmail is the very well - know example
# - Hope we are all known about spam folder too
# - Spam
#   1. It is the common term used for junk or unwanted email, such as chain letters, promotions and so on
# - Ham
#   1. It is common term used for non spam mail means useful mail
# - In this scenario machine learning algorithm is working to filter spam or not
# - Machine learning algorithm
#   1. Understand the previews mails(data)
#   2. Based on the previous mail creates some models
#   3. These models applies on upcoming mails and predict whether it is spam or not
#
# ## 20 Banking loan application / credit card
# - Bnaking loan application this is the very common application hope everyone knows
# - Once we applied for loan by submitting required documents(data) like pay slip past 6 month banking statements and etc
# - Then banking guys will run one application over the given data
# - This is Machine learing algorithm
# - This algorithm passes through the data and predictd the weather the loan/ credit card sanctioned or not
#
# ### Note
# - Many other application are using machine learning
# - I would like to say Machine learning is everywhere
#
# ## 21 Where machine learning helps?
# - From past two decades most of the companies are digitalized
# - So here data is generted more and more
# - So this case machine learning helps us to develop predictive models and automate several things
# - Assuming that we have past couple of years amazon transaction data
# - Some question:
#   1. Wanted to know how the business was in last couple of years
#   2. Wanted to take best decision to improve the business and etc
# - To answer above questions , we need to
#   1. Gather the data
#   2. Process the data
#   3. Take the decision
#
# ## 22. Few of machine learning applications
# - Text processing
# - Speech Recognition
# - Traffic prediction
# - Product recommendations
# - Self - driving cars
# - Email spam and malware filtering
# - Online fraud detection
# - Weather forecasting and prediction & etc
#
# ## 23 Why machine learning required
# - As a human we cannot access huge amount of data manually to process
# - We can train machine learning algorithms by providing huge amount of data
# - Machine learning algoithm travel through this data in order to learn about data , it create the model and predict results automatically for new data
#
#
# ## 24 Technically speaking
# - Technically speaking
#   1. WITH THE help of historical data
#   2. MACHINE LEANRING algorithms
#   3. BUILD a mathematical MODEL
#   4. that helps in making PREDICTIONS
#   5. Without being EXPLICITELY PROGRAMMER

# %% [markdown]
# # 20 Decision Tree
#
# ## 1 If dataset is like below example1
# - We can draw a good separation line by using regression algorithm

# %% [markdown]
# ## 2 If dataset is a below example2
# - In the given below scenario, dataset is very complex.
# - Then a single line may not fit for the given dataset
# - Here decision tree comes into the picture

# %% [markdown]
# ## 3 Decision Tree Classification ALgorithm
# - Decision Tree is a supervised learning technique
# - It can be used for both classification and Regreesion problems, but mostly it is preferred for solving Classification problem
# - It is called a decision tree because similar to a tree struture like it starts with the root node and expands on further branches and constructs a tree - like structure
# - In a Decision tree there are two nodes
#   - Decision Node
#   - Leaf Node

# %% [markdown]
# ## 3.1 Decision Node
# - Decision node are used to make any decision and have multiple branches.

# %% [markdown]
# ## 3.2 Leaf nodes
# - Leaf node are the output of those decisions and do not contains any further branches
#
#
# ## 4 CART algorithm
# - In order to build a tree , we use the CART algorithm which stands for classification and Regression Tree algorithm.
# - A decision tree simply asks a question, and based on the answer (Yes/No), it further split the tree into subtrees
#
#
# ## 5 Why use Decision Trees .?
# - Decision Trees usually mimic humans thinking ablilty while making a decision so it is easy to understand.
# - The logic behind the decision tree can be easily understood because it shows a tree-like struture
#
#
# ## 6 Decision Tree Terminologied
#
# ### 6.1 Root Node
# - Root node is from where the decision tree starts
# - It represents the entrie dataset, which further gets divided into two or more homogeneous sets
#
# ### 6.2 Leaf Node
# - Leaf nodes are final output node
# - The tree cannot be segregated further after getting leaf node
#
# ### 6.3 Splitting
# - Splitting is the process of dividing the decision node/root node into sub - node according to the giving conditions.
#
# ### 6.4 Branch/Sub Tree
# - A tree formed by splitting the tree
#
# ### 6.5 Pruning
# - Pruning is the process of removing the unwanted branches from the tree
#
# ### 6.6 Parent/Child node
# - The root node of the tree is called the parent node, and other nodes are called the child nodes
#
#
# ## 7 How does the Decision Tree algorithm works.?
# - Step 1 :- Begin the tree with the root node, which contains the complete dataset
# - Step 2 :- Find the best attribute in the dataset using Attribute Selection Measure(ASM).
# - Step 3 :- Divide the Dataset into subsets the contains possible values for the best attributes.
# - Step 4 :- Generate the decision tree node , which contains the best attribute
# - Step 5 :- Recursively make new decision trees using the subsets of the dataset created in step 3 Continue this process until a stage is reached where you cannot further classify the node and called the final node as a leaf node
#
#
# ## 7.1 Example
# - Suppose there is a candidate who has a job offer and wants to decide whether he should accept the offer or Not.
# - So, to solve this problem, the decision tree starts with the root node (Salary attribute by ASM).
# - The root node splits further into the next decision node (distance from the office) and one leaf node based on the corresponding labels.
# - The next decision node further gets split into one decision node (Cab facility) and one leaf rode.
# - Finally, the decision node splits into two leaf nodes (Accepted offers and Declined offer
#
# ## 8 Problem

# %%
# step 1 Importing Libraries
import pandas as pd

# step 2 Loading the dataset
df=pd.read_csv("/Users/apple/Downloads/salary_data.csv")
print(df)
# Out:
#        Company                  Job     Degree  Salary_more_than_100k
# 0       google      sales executive  bachelors                      0
# 1       google      sales executive    masters                      0
# 2       google     business manager  bachelors                      1
# 3       google     business manager    masters                      1
# 4       google  computer programmer  bachelors                      0
# 5       google  computer programmer    masters                      1
# 6   abc pharma      sales executive    masters                      0
# 7   abc pharma  computer programmer  bachelors                      0
# 8   abc pharma     business manager  bachelors                      0
# 9   abc pharma     business manager    masters                      1
# 10    facebook      sales executive  bachelors                      1
# 11    facebook      sales executive    masters                      1
# ...

# %%
# Preparing input and target

# step 1 Importing Libraries
import pandas as pd

# step 2 Loading the dataset
df=pd.read_csv("/Users/apple/Downloads/salary_data.csv")


# step 3 Data Preparation 
inputs=df.drop("Salary_more_than_100k",axis="columns")
target=df.Salary_more_than_100k

print("Input")
print(inputs.head())

print()

print("Target")
print(target.head())
# Out:
# Input
#   Company                  Job     Degree
# 0  google      sales executive  bachelors
# 1  google      sales executive    masters
# 2  google     business manager  bachelors
# 3  google     business manager    masters
# 4  google  computer programmer  bachelors
#
# Target
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# Name: Salary_more_than_100k, dtype: int64

# %%
# step 1 Importing Libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# step 2 Loading the dataset
df=pd.read_csv("/Users/apple/Downloads/salary_data.csv")


# step 3 Data Preparation 
inputs=df.drop("Salary_more_than_100k",axis="columns")
target=df.Salary_more_than_100k

# step 3a Data Preparation 
le_company=LabelEncoder()
inputs["company_n"]=le_company.fit_transform(inputs["Company"])

print(inputs)
# Out:
#        Company                  Job     Degree  company_n
# 0       google      sales executive  bachelors          2
# 1       google      sales executive    masters          2
# 2       google     business manager  bachelors          2
# 3       google     business manager    masters          2
# 4       google  computer programmer  bachelors          2
# 5       google  computer programmer    masters          2
# 6   abc pharma      sales executive    masters          0
# 7   abc pharma  computer programmer  bachelors          0
# 8   abc pharma     business manager  bachelors          0
# 9   abc pharma     business manager    masters          0
# 10    facebook      sales executive  bachelors          1
# 11    facebook      sales executive    masters          1
# 12    facebook     business manager  bachelors          1
# 13    facebook     business manager    masters          1
# 14    facebook  computer programmer  bachelors          1
# ...

# %%
# step 1 Importing Libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# step 2 Loading the dataset
df=pd.read_csv("/Users/apple/Downloads/salary_data.csv")


# step 3 Data Preparation 
inputs=df.drop("Salary_more_than_100k",axis="columns")
target=df.Salary_more_than_100k

# step 3a Data Preparation 
le_company=LabelEncoder()
inputs["company_n"]=le_company.fit_transform(inputs["Company"])
inputs["Job_n"]=le_company.fit_transform(inputs["Job"])
inputs["Degree_n"]=le_company.fit_transform(inputs["Degree"])

print(inputs)
# Out:
#        Company                  Job     Degree  company_n  Job_n  Degree_n
# 0       google      sales executive  bachelors          2      2         0
# 1       google      sales executive    masters          2      2         1
# 2       google     business manager  bachelors          2      0         0
# 3       google     business manager    masters          2      0         1
# 4       google  computer programmer  bachelors          2      1         0
# 5       google  computer programmer    masters          2      1         1
# 6   abc pharma      sales executive    masters          0      2         1
# 7   abc pharma  computer programmer  bachelors          0      1         0
# 8   abc pharma     business manager  bachelors          0      0         0
# 9   abc pharma     business manager    masters          0      0         1
# 10    facebook      sales executive  bachelors          1      2         0
# ...

# %%
# step 1 Importing Libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# step 2 Loading the dataset
df=pd.read_csv("/Users/apple/Downloads/salary_data.csv")


# step 3 Data Preparation 
inputs=df.drop("Salary_more_than_100k",axis="columns")
target=df.Salary_more_than_100k

# step 3a Data Preparation 
le_company=LabelEncoder()
inputs["company_n"]=le_company.fit_transform(inputs["Company"])
inputs["Job_n"]=le_company.fit_transform(inputs["Job"])
inputs["Degree_n"]=le_company.fit_transform(inputs["Degree"])

inputs_n=inputs.drop(["Company","Job","Degree"],axis="columns")

print(inputs_n)
# Out:
#     company_n  Job_n  Degree_n
# 0           2      2         0
# 1           2      2         1
# 2           2      0         0
# 3           2      0         1
# 4           2      1         0
# 5           2      1         1
# 6           0      2         1
# 7           0      1         0
# 8           0      0         0
# 9           0      0         1
# 10          1      2         0
# 11          1      2         1
# 12          1      0         0
# 13          1      0         1
# 14          1      1         0
# 15          1      1         1

# %% [markdown]
# ## 9 DecisionTreeCLassifier class
# - DecisionTreeClassifier is predefined class in sklearn.tree package
# - We need to import this class from sklearn.tree package
# - Once we impotred then we need to create an object to DecisionTreeClassifier class.
#
# ## Decision Tree Algorithm
# # - 1 Regression => DecisionTreeRegressor
# # - Classification => DecisionTreeClassifier

# %%
# Step 1 Importing libraries 
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

# Step 2 Loading Dataset 
df=pd.read_csv("/Users/apple/Downloads/salary_data.csv")
#print(df)

# Step 3 Data prepartion
inputs=df.drop("Salary_more_than_100k",axis="columns")
target=df.Salary_more_than_100k

# Step 3a Data prepartion
le_company=LabelEncoder()
inputs["company_n"]=le_company.fit_transform(inputs["Company"])
inputs["job_n"]=le_company.fit_transform(inputs["Job"])
inputs["Degree_n"]=le_company.fit_transform(inputs["Degree"])

inputs_n=inputs.drop(["Company","Job","Degree"],axis="columns")

#print(inputs_n)

# Step 4 Splitting the dataset : optional because dataset is small

# Step 5 Model creations

model=DecisionTreeClassifier()
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## 9.1 fit(X_train,y_train) method
# # - fit(X_train,y_train) is predefined method in DecisionTreeCLassifier class
# - We should access this method by using DecisionTreeCLassifier object only
# - By using this method we need to tain the model

# %%
# Step 1 Importing libraries 
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

# Step 2 Loading Dataset 
df=pd.read_csv("/Users/apple/Downloads/salary_data.csv")
#print(df)

# Step 3 Data prepartion
inputs=df.drop("Salary_more_than_100k",axis="columns")
target=df.Salary_more_than_100k

# Step 3a Data prepartion
le_company=LabelEncoder()
inputs["company_n"]=le_company.fit_transform(inputs["Company"])
inputs["job_n"]=le_company.fit_transform(inputs["Job"])
inputs["Degree_n"]=le_company.fit_transform(inputs["Degree"])

inputs_n=inputs.drop(["Company","Job","Degree"],axis="columns")

#print(inputs_n)

# Step 4 Splitting the dataset : optional because dataset is small

# Step 5 Model creations

model=DecisionTreeClassifier()


# Step 6 Model training 
model.fit(inputs_n.values,target)
# Out:
# DecisionTreeClassifier()

# %%
# checking the scoure

# Step 1 Importing libraries 
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

# Step 2 Loading Dataset 
df=pd.read_csv("/Users/apple/Downloads/salary_data.csv")
#print(df)

# Step 3 Data prepartion
inputs=df.drop("Salary_more_than_100k",axis="columns")
target=df.Salary_more_than_100k

# Step 3a Data prepartion
le_company=LabelEncoder()
inputs["company_n"]=le_company.fit_transform(inputs["Company"])
inputs["job_n"]=le_company.fit_transform(inputs["Job"])
inputs["Degree_n"]=le_company.fit_transform(inputs["Degree"])

inputs_n=inputs.drop(["Company","Job","Degree"],axis="columns")

#print(inputs_n)

# Step 4 Splitting the dataset : optional because dataset is small

# Step 5 Model creations

model=DecisionTreeClassifier()


# Step 6 Model training 
model.fit(inputs_n.values,target)


# Checking thr score

print(model.score(inputs_n.values,target))
# Out:
# 1.0

# %% [markdown]
# ## 9.2 predict(p) method
# - predict(p) is predefined method in DecisionTreeCLassifier class.
# - We should access this method by using DecisionTreeClassifier object only
# - By using this method we can predict the reslts

# %%
# prediction the model

# Step 1 Importing libraries 
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

# Step 2 Loading Dataset 
df=pd.read_csv("/Users/apple/Downloads/salary_data.csv")
#print(df)

# Step 3 Data prepartion
inputs=df.drop("Salary_more_than_100k",axis="columns")
target=df.Salary_more_than_100k

# Step 3a Data prepartion
le_company=LabelEncoder()
inputs["company_n"]=le_company.fit_transform(inputs["Company"])
inputs["job_n"]=le_company.fit_transform(inputs["Job"])
inputs["Degree_n"]=le_company.fit_transform(inputs["Degree"])

print(inputs)

inputs_n=inputs.drop(["Company","Job","Degree"],axis="columns")

#print(inputs_n)

# Step 4 Splitting the dataset : optional because dataset is small

# Step 5 Model creations

model=DecisionTreeClassifier()


# Step 6 Model training 
model.fit(inputs_n.values,target)


print(50*"*")

print(" Step 7 preciction")
print()
print(model.predict([[2,1,0]]))
# Out:
#        Company                  Job     Degree  company_n  job_n  Degree_n
# 0       google      sales executive  bachelors          2      2         0
# 1       google      sales executive    masters          2      2         1
# 2       google     business manager  bachelors          2      0         0
# 3       google     business manager    masters          2      0         1
# 4       google  computer programmer  bachelors          2      1         0
# 5       google  computer programmer    masters          2      1         1
# 6   abc pharma      sales executive    masters          0      2         1
# 7   abc pharma  computer programmer  bachelors          0      1         0
# 8   abc pharma     business manager  bachelors          0      0         0
# 9   abc pharma     business manager    masters          0      0         1
# 10    facebook      sales executive  bachelors          1      2         0
# ...

# %%
print(model.predict([[2,1,1]]))
# Out:
# [1]

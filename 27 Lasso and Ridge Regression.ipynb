# %% [markdown]
# # => Lasso & Ridge regression
#
#
# ### How to list out imp cols.?
# - Domain expert
# - XGBoost alg
#
# ## Lasso Regression / L1 penalty
# - Whenever we are applying Lass Regression then the backend math function will be
# - Sum of the absolute coefficient values
#
# ## Ridge Regression  / L2 penalty
#  - Whenever we are applying Lass Regression then the backend math function will be
# - Sum of the squared coefficient values

# %% [markdown]
# ## Overfitting
# - We are giving training to ML algorithm - Model training
# - We are testing (prediction) by using model the model
#
# # Overfitting
# ## Model
# - Training => check the score => 70/100 goood score
# - Testing => check the score =>  19/100  bad score
#
# # underfitting
# ## Model
# - Training => check the score => 10/100  bad score
# - Testing => check the score =>  19/100  bad score
#
# # Model training DOne
# ## Problems   WE need to fix ? How to fix .?  => By using Lasso & Ridge regression
# 1. Overfitting => Very Serious problem
# 2. Underfitting => not a much a problem
#
# ## 1 Linear Regression
# - Linear Regression is a standard algorithm for regression and it is used to explain the relationship between a two variable.
# - Also called as it's relationship in between dependent variable and one or more independent variables
#
# ## 2 Lasso Regression
# - In linear regression with a single input variable this relationship is a line and with higher dimension this relationship can be hyperplane that connects the input variables to the target variable.
# - The coefficients of the model are found via an optimization process which minimize error
#
# ## 3 Coefficients can be large
# - A limitaion with linear regression the estimsted coefficients of the model can become large and may become model unstable
# - One approach to address the stablility of regression models is to change the loss function to include additional costs for a model that has large coefficients
#
# ## 4 L1 penalty
# - Lasso Regression is a popular type of regularized linear regression that include a L1 penalty
# # - It penalize a model based on the sum of the absolute coefficient values This is called the L1 penalty
# - An L1 penalty minimizes the size of all coefficients and some coefficient to be minimized to the value zero effectively removing input features from the model
#
# ## 5 L1 Regularization
# - A regression model that uses L1 regression technique is called Lasso Regression
# - Lasso full form is Least Absolute Shrinkage and Selection Operator
#
# ## 6 How to aviod overfitting issue .?
# - Regularization is an important concept that is used to aviod overfitting of the data
# - We can address this issue by using L1 and L2 Regularization
# - Regularization is implementd by adding a "penalty" term to the best fit derived from the trained data , to achieve a lesser variance
#
# ## 7 L1 Regularization and L2 Regularization
# - When you have a large number of feature in your dataset , some of the Regularization techniques used to address over-fitting

# %%
# Importing required libraries 

import pandas as pd 
import numpy as np

import warnings
warnings.filterwarnings('ignore')

print("Importing required libraries")
# Out:
# Importing required libraries

# %%
# Dataset 

import pandas as pd

df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")


print(df.head())
print()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %% [markdown]
# ## 8 Dataset Details : Melbourene house sale price
# - The dataset is about the housing market in Melbourne and contains infomation about the house sale price
# - Notes on Specific Variables
#   - Rooms : Number of rooms
#   - Price : Price in dollars
#   - Method S : property sold; SP - property sold prior; PI - property passed in ; PN - sold prior not disclosed; SN- sold not disclose; NB - no bid; VB - vendor bid ; W - withdrawn prior to auction; SA - sold after auction; SS - sold after auction price not disclose. N/A - price or highest bid not available.
#   - Type : br -bedroom(s); h - house , cottage , villa , semi , terrace ; u - unit , duplex; t - townhouse; dev site - development site; o res - other residential
#   - SellerG : Real Estate Agent

# %%
# Rows and columns in Dataframe 

import numpy as np
import pandas as pd 

import warnings
warnings.filterwarnings("ignore")

df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")

print("Row and columns:" ,df.shape)
# Out:
# Row and columns: (13580, 21)

# %%
# Uniaue values

import pandas as pd

df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")

print(df.nunique())
# Out:
# Suburb             314
# Address          13378
# Rooms                9
# Type                 3
# Price             2204
# Method               5
# SellerG            268
# Date                58
# Distance           202
# Postcode           198
# Bedroom2            12
# Bathroom             9
# Car                 11
# Landsize          1448
# BuildingArea       602
# YearBuilt          144
# CouncilArea         33
# Lattitude         6503
# Longtitude        7063
# Regionname           8
# Propertycount      311
# dtype: int64

# %%
# Get the required columns 


# step 1 importing libraries
import pandas as pd


#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")

cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]

print(df.head())
print()
print(df.shape)
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
# 3  Abbotsford      3    h     PI  Biggin  Northern Metropolitan
# 4  Abbotsford      4    h     VB  Nelson  Northern Metropolitan
#
#    Propertycount  Distance CouncilArea  Bedroom2  Bathroom  Car  Landsize  \
# 0         4019.0       2.5       Yarra       2.0       1.0  1.0     202.0
# 1         4019.0       2.5       Yarra       2.0       1.0  0.0     156.0
# 2         4019.0       2.5       Yarra       3.0       2.0  0.0     134.0
# 3         4019.0       2.5       Yarra       3.0       2.0  1.0      94.0
# 4         4019.0       2.5       Yarra       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price
# 0           NaN  1480000.0
# 1          79.0  1035000.0
# 2         150.0  1465000.0
# ...

# %%
# Rows and columns in Dataframe 

# step 1 importing libraries
import pandas as pd

#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")

cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]

print(df.shape)
# Out:
# (13580, 15)

# %%
# Checking NaN values

# step 1 importing libraries
import pandas as pd

#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")

cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]

print(df.isna().sum())
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          0
# Propertycount       0
# Distance            0
# CouncilArea      1369
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# Price               0
# dtype: int64

# %%
# Filling Car and BuildingArea columns with mean value 

# step 1 importing libraries
import pandas as pd

#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")

cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]


# Filling Car and BuildingArea columns with mean value 
df["Car"]=df["Car"].fillna(df.Car.mean())
df["Landsize"]=df["Landsize"].fillna(df.Landsize.mean())
df["BuildingArea"]=df["BuildingArea"].fillna(df.BuildingArea.mean())


print(df.isna().sum())
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          0
# Propertycount       0
# Distance            0
# CouncilArea      1369
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# Price               0
# dtype: int64

# %%
# Dropping NaN values

# step 1 importing libraries
import pandas as pd

#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")

cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]


# Filling Car and BuildingArea columns with mean value 
df["Car"]=df["Car"].fillna(df.Car.mean())
df["Landsize"]=df["Landsize"].fillna(df.Landsize.mean())
df["BuildingArea"]=df["BuildingArea"].fillna(df.BuildingArea.mean())

df.dropna(inplace=True)

print(df.isna().sum())
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
# Creating dummy variables for character data 

# step 1 importing libraries
import pandas as pd

#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")


# step 3a  EDA
cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]

# Filling Car and BuildingArea columns with mean value 
df["Car"]=df["Car"].fillna(df.Car.mean())
df["Landsize"]=df["Landsize"].fillna(df.Landsize.mean())
df["BuildingArea"]=df["BuildingArea"].fillna(df.BuildingArea.mean())

df.dropna(inplace=True)

df=pd.get_dummies(df,drop_first=True)

print(df.shape)
# Out:
# (12211, 613)

# %%
# Creating dummy variables for character data 

# step 1 importing libraries
import pandas as pd

#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")


# step 3a  EDA
cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]

# Filling Car and BuildingArea columns with mean value 
df["Car"]=df["Car"].fillna(df.Car.mean())
df["Landsize"]=df["Landsize"].fillna(df.Landsize.mean())
df["BuildingArea"]=df["BuildingArea"].fillna(df.BuildingArea.mean())

df.dropna(inplace=True)

df=pd.get_dummies(df,drop_first=True)

print(df.head())
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0      2         4019.0       2.5       2.0       1.0  1.0     202.0
# 1      2         4019.0       2.5       2.0       1.0  0.0     156.0
# 2      3         4019.0       2.5       3.0       2.0  0.0     134.0
# 3      3         4019.0       2.5       3.0       2.0  1.0      94.0
# 4      4         4019.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price  Suburb_Aberfeldie  ...  CouncilArea_Moreland  \
# 0     151.96765  1480000.0              False  ...                 False
# 1      79.00000  1035000.0              False  ...                 False
# 2     150.00000  1465000.0              False  ...                 False
# 3     151.96765   850000.0              False  ...                 False
# 4     142.00000  1600000.0              False  ...                 False
#
#    CouncilArea_Nillumbik  CouncilArea_Port Phillip  CouncilArea_Stonnington  \
# ...

# %%
# Data prepareation 

# step 1 importing libraries
import pandas as pd

#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")


# step 3a  EDA
cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]

# Filling Car and BuildingArea columns with mean value 
df["Car"]=df["Car"].fillna(df.Car.mean())
df["Landsize"]=df["Landsize"].fillna(df.Landsize.mean())
df["BuildingArea"]=df["BuildingArea"].fillna(df.BuildingArea.mean())

df.dropna(inplace=True)

df=pd.get_dummies(df,drop_first=True)

# step 3 Data preparation

X=df.drop("Price",axis=1)
y=df["Price"]

#print(X)
#print(y)
# Out:
# <bound method DataFrame.info of        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0          2         4019.0       2.5       2.0       1.0  1.0     202.0
# 1          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 2          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 3          3         4019.0       2.5       3.0       2.0  1.0      94.0
# 4          4         4019.0       2.5       3.0       1.0  2.0     120.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 12208      3         6380.0       6.8       3.0       1.0  0.0     296.0
# 12209      2         4380.0       4.6       2.0       1.0  1.0       0.0
# 12210      3         2940.0      25.5       3.0       2.0  2.0     400.0
# 12211      2         6543.0       6.3       2.0       1.0  2.0     269.0
# 12212      6         6543.0       6.3       6.0       3.0  2.0    1087.0
#
# ...

# %%
# splitting train and test dataset

# step 1 importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split

#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")


# step 3a  EDA
cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]

# Filling Car and BuildingArea columns with mean value 
df["Car"]=df["Car"].fillna(df.Car.mean())
df["Landsize"]=df["Landsize"].fillna(df.Landsize.mean())
df["BuildingArea"]=df["BuildingArea"].fillna(df.BuildingArea.mean())

df.dropna(inplace=True)

df=pd.get_dummies(df,drop_first=True)

# step 3 Data preparation

X=df.drop("Price",axis=1)
y=df["Price"]

# step 4 splitting dataset
X_train,X_test,y_train,y_test=train_test_split(X
                                               ,y
                                               ,train_size=0.3
                                               ,random_state=1)

print("Splitting train and test datasets")
# Out:
# Splitting train and test datasets

# %%
# Creating LinearRegression Model and training 
# step 1 importing libraries

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")


# step 3a  EDA
cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]

# Filling Car and BuildingArea columns with mean value 
df["Car"]=df["Car"].fillna(df.Car.mean())
df["Landsize"]=df["Landsize"].fillna(df.Landsize.mean())
df["BuildingArea"]=df["BuildingArea"].fillna(df.BuildingArea.mean())

df.dropna(inplace=True)

df=pd.get_dummies(df,drop_first=True)

# step 3 Data preparation

X=df.drop("Price",axis=1)
y=df["Price"]


# step 4 splitting dataset
X_train,X_test,y_train,y_test=train_test_split(X
                                               ,y
                                               ,train_size=0.3
                                               ,random_state=1)

# step 5 Model creation 
model=LinearRegression()

# step 6 model training 
model.fit(X_train,y_train)

# Training dataset scores is 
print(model.score(X_train,y_train))

print()

# Testng dataset score
print(model.score(X_test,y_test))
# Out:
# 0.7479678534817726
#
# 0.5367382932791286

# %% [markdown]
# # Note
# - It training score is very good and test score is very low then it called as over fit

# %%
# Lasso Regression 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
import pandas as pd
import warnings
warnings.filterwarnings("ignore")


#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")


# step 3a  EDA
cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]

# Filling Car and BuildingArea columns with mean value 
df["Car"]=df["Car"].fillna(df.Car.mean())
df["Landsize"]=df["Landsize"].fillna(df.Landsize.mean())
df["BuildingArea"]=df["BuildingArea"].fillna(df.BuildingArea.mean())

df.dropna(inplace=True)

df=pd.get_dummies(df,drop_first=True)

# step 3 Data preparation

X=df.drop("Price",axis=1)
y=df["Price"]


# step 4 splitting dataset
X_train,X_test,y_train,y_test=train_test_split(X
                                               ,y
                                               ,train_size=0.3
                                               ,random_state=1)



# step 5 Model creation 
model=Lasso(alpha=50,
            max_iter=100,
            tol=0.1)

# step 6 model training 
model.fit(X_train,y_train)

# Training dataset scores is 
print(model.score(X_train,y_train))

print()

# Testng dataset score
print(model.score(X_test,y_test))
# Out:
# 0.7447454615182496
#
# 0.5502733519370397

# %% [markdown]
# ## 9 Ridge Regression
# - In linear regression with a single input variable this relationship is a line, and with higher dimension , this relationship can be hyperplane that connects the input variables to the target variable.
# - The coefficients of the model are found via an optimization process which minimize error
#
# ## 10 Coeffcients can be large
# - A problem with linear regression , the estimated coefficients of the model can become large and may become model unstable
# - One approach to address the stability of regression models is to change the loss function to include additional costs for a model that has large
#
# ## 11 L2 penalty
# - Ridge Regression is a popular type of regularized linear regression that includes an L2 penalty
# - It penalize a model based on sum of the squared coefficient value. This is called the L2 penalty
# - An L2 penalty minimizes the size of all coefficients and some coefficients to be minimized to the value zero , effectively removing input features from the model

# %%
# Ridge Regression Training training data score

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
import pandas as pd
import warnings
warnings.filterwarnings("ignore")


#  step 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/melb_data.csv")


# step 3a  EDA
cols_to_use=["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]

df=df[cols_to_use]

# Filling Car and BuildingArea columns with mean value 
df["Car"]=df["Car"].fillna(df.Car.mean())
df["Landsize"]=df["Landsize"].fillna(df.Landsize.mean())
df["BuildingArea"]=df["BuildingArea"].fillna(df.BuildingArea.mean())

df.dropna(inplace=True)

df=pd.get_dummies(df,drop_first=True)

# step 3 Data preparation

X=df.drop("Price",axis=1)
y=df["Price"]

# step 4 splitting dataset
X_train,X_test,y_train,y_test=train_test_split(X
                                               ,y
                                               ,train_size=0.3
                                               ,random_state=1)



# step 5 Model creation 
model=Lasso(alpha=50,
            max_iter=100,
            tol=0.1)

# step 6 model training 
model.fit(X_train,y_train)

# Training dataset scores is 
print(model.score(X_train,y_train))

print()

# Testng dataset score
print(model.score(X_test,y_test))
# Out:
# 0.7447454615182496
#
# 0.5502733519370397

# %% [markdown]
# ### model => Overfitting  model
# - Training score good
# - Testing score not good
#
# #### Why .?
# - Coef... => Very large values

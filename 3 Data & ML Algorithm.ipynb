# %% [markdown]
# # 3 Data & ML Algorithm

# %% [markdown]
# ## 1 Data
# - It is a collection of facts
# - facts mean
#   1. Alphabets
#   2. Numbers
#   3. Alphanumeric
#   4. Symbol
#
# ## 2 Data in table
# - Generally tables having data like rows , columns and cells
# - Tabular data is very easy to understand
#
# ## 3 Row
# - A row describes a single entity or observation
# - A row is also called a record
#
# ## 4 Column
# - A column is a vertical group of cells within table
# - A column having same type of values
# - In column we can store the data like weights heights and prices etc info
#
# ## 5 Cell
# - A cell is a sinale value in a row and column
# - It may be a real value (1.5) an integer (2) or a category (red)
#
# ## 6 Statistical learning Prespecctive
# - In statistical learning prespective data means
#   1. It is the context of a Hypothetical function (f) that the machine learning algorithm is trying to learn
#
# ## 6.1 Example
# - Assuming that there is a former in village  and initially he had 1 acre land
# - While forming rice it get yields as below
#
# | Area | Rice packets |
# |------|--------------|
# | 1    | 10           |
# | 2    | 20           |
# | 3    | 30           |
#
#
#
# ## 7 Why MAchine learning algorithms learn this funtion .?
# - To predict output for the given input
#   - output=f(input)
# - Columns are calleed as input variables
# - Predicted result is called as output variable or response variable
#   - Output Variable = f(input variables)
#
# | A  |  X1  |  X2  |  Y   |   |  Y |
# |----|------|------|------|----|----|
# | 1  |      |      |      |    |    |
# | 2  | 2.2  | 2.3  | 1    |    | 1  |
# | 3  | 2.3  | 2.6  | 0    |    | 0  |
# | 4  | 2.1  | 2    | 1    |    | 1  |
#
#
# - Input data have more than one input variable
# - The group of input variable are called as input vector
#   -   - Output Variable = f(input variables)
#
# ## 8 Terminology in statistics
# - Input variable are called as Independent Variables
# - Output variable are called as the Dependent variable
# - Here the output is dependent on a function of input
#  - Dependent Variable = f(Indepentent Variables)
# - Input variable representing with X
# - Output variable representing with Y
#    - Y = f(X)
# - If we have multiple input variable then its represent as input vector x1,x2,x3 for the data
#
# ## 9 Computer Science Prespective
# - A row means its an entity / observation / object in a table
# - A column is called as an attribute
# - During modeling and predictions
#   - Input is called as input attribute
#   - Output is called as output attribute
# - Output Attribute = Program( Input Attributes )
#
# | Area | Rice packets |
# |------|--------------|
# | 1    | 10           |
# | 2    | 20           |
# | 3    | 30           |
#
# - Output = Program(Input Feature)
# - Prediction output = Program(Instance)
#
# # 10 Model and Algorithms
# - A model is a specific respresentation learned from Data and the algorith as the process of learning it
#   - Model = Algorithm(Data)

# %% [markdown]
# # Imp formula
# - y=f(x)
# - dependet variable = independent variable * 10
# - Model = Algorithm(Data)

# %% [markdown]
# # Machine learning
# - Machine learning algorthim is learning (math formulas)from data

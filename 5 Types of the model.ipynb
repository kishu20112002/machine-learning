# %% [markdown]
# # 5 Types of the Models (veryyyy   imp)
# - In Machine learning there are mainly 3 types of model exist
#   - Supervised learning
#   - Unsupervised learning
#   - Reinforcement learning
# # Best tip
# - Before understanding the type of algorthim lets try to understand terminolgy

# %% [markdown]
# - Supevised learning = Freatures(input) + target(Output)
# - Unsupervised learning = Features

# %% [markdown]
# ## 1 Feature and label
# ### 1.1 Features
# - Feature are simply the columns of the table
# - These feature describes the about the data
# - In the given data, Age , Gender , Experience and salary are features
#
# | Age | Gender | Experience | Salary |
# |-----|--------|------------|--------|
# | 20  | M      | 4          | 40000  |
# | 24  | F      | 5          | 50000  |
#
# ### 1.2 Label
# - The output we will get after training the model is called as Label
# - Requirement
#   - Suppose I wanted to predict the salary who had 6 years of experience
#   - We prepared a model and that model predicted the salary
#   - Here salary is called as a label
# - Simple
#   - We a tring to predict a feature based on the others, that feature is the label
#
# ## 2 label Example
# - If we are trying to predict the type of pet for example cat or dog based on information then that is the label
# - If we are trying to predict if the pet is sick or healthy based on symptoms and other infomation then that is the label.
# - If we are trying to predict the age of the pet then the age is the label
#
# ## 3 Labelled and unlabeled data  (very veryy imp interview)
# - According to the label data is divided into two types
#   - Labelled data
#   - Unlabeled data
# ## 3.1 Labelled Data
# - Labelled data comes with a tag or label , like a name , a type , or a number
# ## 3.2 Unlabeled Data
# - Labelled data have no tag or label
#
#
# ## 4 Supervised learning definition
# - In Supervised learning We will train the models by using input features and labels
#
# ## 5 Unsupervised Learning definition
# - In unsupervised learning we will train the models by using only input features and there is not labels
# - ## Unsupervised machine learning by unsuperisted learning groups your data
#
# ## 6 Supervied learning example
# - Now a day it is very commonly  using for all applications
# - Supervised learning = feature + label
# - Example
#   - Image recognition
#   - Test processing
#   - Recommendation system & many more
#
# ## Scenario
# - In previous image we have an image we have an image data about dogs and cates
# - Labels in the image are dog and cat
# - The machine learning model use previous data in order to predict the label of new data points
#
# ## 7 Remember - formulate - Predict
# - Supervised learning works in remember - formulate - predict
# - The model first remembers the dataset of dogs and cate
# - Then model formulates a model for what is a dog and what is a cat
# - Whenever a new image comes in the model makes a prediction about what the label of the image weather cat or dog
#
# ## 8 Types of Supervised learning models (very imp interview )
# - Supervised learning models are divided into two types
#   ### - Regression models  => Predict nuber , example sales==numbers,age==number
#   ### - Classification models => predict classify/class/category ex person==male/female , rain == yes/no,image==cat/dog
#
# ### 8.1 Regression models
# - Regression models used to predict a number
# - The output of a regression model is a continuous since the prediction can be any real value
# - Examples:
#   - Weight of the animal
#   - Employee salary
#   - Students marks
#   - Stock market
#   - Number of sales
#   - Predicting price of house & etc
#
# ### 8.2 Classification models
# - These are the types of models that predict the class or state
# - Examples
#   - Types of animal (cat or dog)
#   - Types of human being means male or female
#   - Biryani taste: good or bad or not good
#   - Mail id spam or ham
#
# # Regression
# - What is the temperature going to be tomorrow ? => 84
# # CLassification
# - Will it be cold or hot tomorrw ? Cold/hot
#
# ## 9 Unsupervised learning example
# - It groups of the data based on similaries
# - In unsupervied learning we will train the models by using only input features but there are no labels
# - Unsupervised learning is grouping the data based on similarities
#
# ## 10 Types of Unsupervised learning models (very imp )
# - Unsupervised learning models are divided into two types
#   1. Clustering
#   2. Dimensionality reduction
#
# ### 10.1 Clustering
# - This is the task of grouping our data into clusters based on similarity by colour , by shape , by size
#
# ### 10.2 Dimensionality reduction
# - Dimension means => coloumn name
# - Reduction means => delect or remove to get good preformance
# - This is task of simplifying our data and describing it with fewer features, without losing much generlity
# - The dimensionality reduction algorithms will finds ways that group them losing as little infomation as possible

# %% [markdown]
# # ML steps
# 1. Importing libraries
# 2. Loading the dataset
# 3. splitting the dataset
# 4. data preparation
# 5. Model creation
# 6. Model training
# 7. Prediction
#
# # ML Models
# 1. Supervised
#    1. Regression
#    2. Classfication
# 2. Unsupervised
#    1. Clustering
#    2. Dimentionality Reduction
# 3. Reinforcements == AI

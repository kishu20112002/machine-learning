# %% [markdown]
# # 9 Simple Linear Regression

# %% [markdown]
# ## Machine Learning - First Algorithm
# # hello worls examples
# ## - Python => print("hello world")
# ## - Pandas => Creating Series/DataFrame
# ## - Numpy => Creating an array
# ## - ML => Simple Liear Regression Algorithm

# %% [markdown]
# # Machine Learning Steps
# ### 1. Importing libraries
# ### 2. Loading the datasets
# ### 3. Data preparation : input x, output y
# ### 4. Splitting the dataset
# ### 5. Creating the model (Algorithm)
# ### 6. Model training
# ### 7. Prediction

# %% [markdown]
# ## 1 Regression
# # - Regression Explain the relationship between two variables
# # - Regression the relationship between Dependent variables and independet variables
# - Regression analysis is used to explain the relationship between a two variables
# - Also called as it is a realationship in between dependent variable and one or more independent variables
#
# ## 2 A line
# # - Regression the relation between twi variable we can draw a line in between two variables
# - If two variables having relationship then if we draw this relationship in a two dimensional then we get a straight line
# - The picture of linear regression is simple
# - let us say we have some points a line will travel in between these points
#
# ## 3 The goal
# - The goal of linear regression is draw the best fitted line
# - Best fitted line means that the line which passes as close as possible to these points
#
# ## 4 Linear Regression
# - This is a techique and it explains the relationship between the dependent variable and independent variable
#
# ## 5 Types of linear regression
# - There are two types of linear regression
#   1. Simple linear regression  => 2 variables
#   2. Multiple linear regression => more then 2 variavle
#
# ## 6 Simple linear regression
# - One dependent variable
# - One independent variable
# - When you have only 1 independent variable and 1 dependent variable it is called simple linear regression
#
# ## 7 Mulitplie linear regression
# - When you have 2 or more independent variable and 1 dependent variable it is called multipleinear regression
#
# ## 8 Simple linear regression example
# - when you have only 1 independent variable and 1 dependent vaariable it is called simple linear regresssion
#
# ## 8.1 Problem statement
# - Assuming that we are planning to buy a new house and need to predict the price of a house
#
# ## 8.2 The solution
# - While buying house first we need to check the area of the house
#
# | area | price   |
# |------|---------|
# | 2600 | 550000  |
# | 3000 | 565000  |
# | 3200 | 610000  |
# | 3600 | 680000  |
# | 4000 | 725000  |
#
#
# ## 9 Machinr learning Terminology
#
# ### 9.1 Feature
# - From the given problem the feature is area and price
#
# ### 9.2 Label or target
# - Price of the house
#
# ### 9.3 Models
# - A Machine learning model is simply a rule or a formula , which predicts a label from the features
# - In the case the model is the equation we found for the price
#
# ### 9.4 Prediction
# - The prediction is simply the output of the model
# - If the model gives the result as "hey guru i think the house with 360000 area is going to cost $300" then the prediction is 300
#
# ### 9.5 Formula
# - Home price = m * (area) + b
#
# ### Reminder
# - Once please walk throuth our maths regression chapter 7 sataistic part 7 regression which we have already discussed
#
# # linder regression
# ## y = mx + c
# ## Home price = m * (area) + b

# %%
#"Step 1 : Importing libraries
#"Step 2 : Loading Dataset ")
# Loading house price dataset

print("Purpose : learning Simple Linear Regre")

print("Step 1 : Importing libraries")
import pandas as pd

print("Step 2 : Loading Dataset ")
df=pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
#print(df)
print()

print(df.shape)
print()

print(df.columns)
print()

df.info()
# Out:
# Purpose : learning Simple Linear Regre
# Step 1 : Importing libraries
# Step 2 : Loading Dataset
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
#
# (5, 2)
#
# Index(['area', 'price'], dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    5 non-null      int64
#  1   price   5 non-null      int64
# dtypes: int64(2)
# memory usage: 212.0 bytes

# %%
# Creating scatter plot using matplotlib

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("/Users/apple/Downloads/area_price_table.csv")

# plotting the dataset

plt.xlabel('area')
plt.ylabel('price')

plt.scatter(df.area,df.price,color='red',marker='*')

plt.show()

# %%
# step 2a : Data vizz

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("/Users/apple/Downloads/area_price_table.csv")

plt.xlabel("area")
plt.ylabel("price")

plt.scatter(df.area,df.price,color='blue',marker="*")

plt.show()

# %% [markdown]
# # Conclusion : As per the diagram there is a relation between area and price

# %% [markdown]
# # First Machine Learning
# ### 1. Importing class
# ### 2. Creating object to class
# #### 3. Access the method by using object
#
# # Machine Learning Steps
# ### 1. Importing libraries
# ### 2. Loading the datasets
# ### 3. Data preparation => df = area(input(X)), price(output(y))
# ### 4. Splitting the dataset
# ### 5. Creating the model (Algorithm)
# ### 6. Model training
# ### 7. Prediction

# %%
# step 3 Data preparation

# %%
# step 4 Splitting the dataset

# %%
# step 5 Model creation(Algorithm)
# Loading the dataset

import pandas as pd
from sklearn.linear_model import LinearRegression

df=pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
new_df=df.drop("price",axis='columns')

print(df)
print()
print(new_df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
#
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
# step 5 Model creation(Algorithm)
# Loading the dataset

import pandas as pd
from sklearn.linear_model import LinearRegression

df=pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
print(df)

new_df=df.drop("price",axis='columns')

print()
print(new_df)

model=LinearRegression()

#model.fit(input,output)
#model.fit(X,y)
model.fit(df.area,df. price)

print()
print()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
#
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 15
#      12 print()
#      13 print(new_df)
# ---> 15 result=LinearRegression(df)
#      17 print()
#      18 print(result)
#
# TypeError: LinearRegression.__init__() takes 1 positional argument but 2 were given

# %%
# step 6 model training

import pandas as pd 
from sklearn.linear_model import LinearRegression

df=pd.read_csv("/Users/apple/Downloads/area_price_table.csv")

new_df=df.drop("price",axis='columns')

print(new_df.values)    # input in col  values converting into array
print()
print(df.price.values)  # output in row
# Out:
# [[2600]
#  [3000]
#  [3200]
#  [3600]
#  [4000]]
#
# [550000 565000 610000 680000 725000]

# %% [markdown]
# ### model creatind
# ## model = LinerRegression()
# ## model.fit(area,price)
# ## model.fir(x,y)
# ## => model.fit(input,output)
#
# # => input => please provide coloumn formate only
# # => output => please provide row formate only

# %%
# step 6 model training
print(50*"*")
print("step 1 : importing lib")
import pandas as pd 
from sklearn.linear_model import LinearRegression


print(50*"*")
print("Step 2 : loading datset")
df=pd.read_csv("/Users/apple/Downloads/area_price_table.csv")

new_df=df.drop("price",axis='columns')

print(new_df.values)    # input in col  values converting into array
print()
print(df.price.values)  # output in row 


print(50*"*")
print("Step 3 : Data preparation")
X=new_df.values
y=df.price.values


print(50*"*")
print("Step 4 : Splitting the dataset")


print(50*"*")
print("Step 5 : Model creation ")
model=LinearRegression()


print(50*"*")
print("Step 6 : Model training")
#model.fit(p1(input),p2(output))
model.fit(X,y)
# Out:
# **************************************************
# step 1 : importing lib
# **************************************************
# Step 2 : loading datset
# [[2600]
#  [3000]
#  [3200]
#  [3600]
#  [4000]]
#
# [550000 565000 610000 680000 725000]
# **************************************************
# Step 3 : Data preparation
# **************************************************
# Step 4 : Splitting the dataset
# **************************************************
# Step 5 : Model creation
# **************************************************
# Step 6 : Model training
# LinearRegression()

# %% [markdown]
# # Conclusion: here model object means LinearRegression object traind with area_price_table.csv dataset Now We can use this object to do the prediction

# %%
# step 6 model training
print(50*"*")
print("step 1 : importing lib")
import pandas as pd 
from sklearn.linear_model import LinearRegression


print(50*"*")
print("Step 2 : loading datset")
df=pd.read_csv("/Users/apple/Downloads/area_price_table.csv")

new_df=df.drop("price",axis='columns')

print(new_df.values)    # input in col  values converting into array
print()
print(df.price.values)  # output in row 


print(50*"*")
print("Step 3 : Data preparation")
X=new_df.values
y=df.price.values


print(50*"*")
print("Step 4 : Splitting the dataset")


print(50*"*")
print("Step 5 : Model creation ")
model=LinearRegression()

print(50*"*")
print("Step 6 : Model training")
#model.fit(p1(input),p2(output))
model.fit(X,y)


print(50*"*")
print("Step 7 : Model Prediction")
print(model.predict([[2800]]))
print(model.predict([[3100]]))
# Out:
# **************************************************
# step 1 : importing lib
# **************************************************
# Step 2 : loading datset
# [[2600]
#  [3000]
#  [3200]
#  [3600]
#  [4000]]
#
# [550000 565000 610000 680000 725000]
# **************************************************
# Step 3 : Data preparation
# **************************************************
# Step 4 : Splitting the dataset
# **************************************************
# Step 5 : Model creation
# **************************************************
# Step 6 : Model training
# **************************************************
# Step 7 : Model Prediction
# [560821.91780822]
# [601558.21917808]

# %%
# ML 
print(50*"*")
print("step 1 : importing libraries")
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

print(50*"*")
print("Step 2 : loading datset")
df=pd.read_csv("/Users/apple/Downloads/area_price_table.csv")

print(df)
new_df=df.drop("price",axis='columns')

print(new_df.values)    # input in col  values converting into array
print()
print(df.price.values)  # output in row 


print(50*"*")
print("Step 3 : Data preparation")
X=new_df.values
y=df.price.values


print(50*"*")
print("Step 4 : Splitting the dataset")
X_train,X_test,ytrain,y_test=train_test_split(X,y)
print(X_train)
print()
print(X_test)
print()
print(10*"*")
print(ytrain)
print()
print(y_test)

print(50*"*")
print("Step 5 : Model creation ")
model=LinearRegression()

print(50*"*")
print("Step 6 : Model training")
#model.fit(p1(input),p2(output))
model.fit(X,y)


print(50*"*")
print("Step 7 : Model Prediction")
print(model.predict([[2800]]))
print(model.predict([[3100]]))
# Out:
# **************************************************
# step 1 : importing libraries
# **************************************************
# Step 2 : loading datset
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
# [[2600]
#  [3000]
#  [3200]
#  [3600]
#  [4000]]
#
# [550000 565000 610000 680000 725000]
# **************************************************
# Step 3 : Data preparation
# **************************************************
# Step 4 : Splitting the dataset
# [[2600]
#  [3000]
#  [3600]]
#
# [[3200]
#  [4000]]
#
# **********
# [550000 565000 680000]
#
# [610000 725000]
# **************************************************
# Step 5 : Model creation
# **************************************************
# Step 6 : Model training
# **************************************************
# Step 7 : Model Prediction
# [560821.91780822]
# [601558.21917808]

# %%
# step 1 : importing lib
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


# step 2 : loading data
df=pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
new_df=df.drop("price",axis="columns")
print(new_df.values)
print(df.price.values)
print()

#step 3 : Data preprapration
X=new_df.values
y=df.price.values

# step 4 : ignore

# step 5 : model creating 
model=LinearRegression()

# step 6 : model traning
model.fit(X,y)

# step 7: prediction
print(model.predict([[2300]]))
# Out:
# [[2600]
#  [3000]
#  [3200]
#  [3600]
#  [4000]]
# [550000 565000 610000 680000 725000]
#
# [492928.08219178]

# %%
#step 1 importing lib
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#ste 2 loading dataset
df=pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
new_df=df.drop("price",axis="columns")
print(new_df)
print(df)
print(50*"*")

print(x)
print()
print(y)
print(50*"*")

# step 3 Dara preprsation
x=new_df.values
y=df.price.values

#step 4 
X_train,X_test=train_test_split(x)
Y_train,y_test=train_test_split(y)

print(X)
print()
print(Y)
#step 5
model=LinearRegression()

#step 6 training
model.fit(X_train,Y_train)

#step 7 prediction
model.predict([[2800]])
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
# **************************************************
# [[2600]
#  [3000]
#  [3200]
#  [3600]
#  [4000]]
#
# [550000 565000 610000 680000 725000]
# **************************************************
# [array([[3200],
#        [4000],
#        [2600]]), array([[3000],
#        [3600]])]
#
# [array([610000, 550000, 725000]), array([565000, 680000])]
# array([587371.79487179])

# %%
#step 1 importing lib
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#step 2 loading dataset
df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
new_df = df.drop("price", axis="columns")
print(new_df)
print(df)
print(50*"*")

# step 3 Data preparation
x = new_df.values
y = df.price.values

# Print x and y AFTER they are defined
print(x)
print()
print(y)
print(50*"*")

#step 4 - Split data correctly
# train_test_split returns 4 arrays: X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(X_train)
print()
print(y_train)

#step 5
model = LinearRegression()

#step 6 training
# fit() requires X and y as separate arguments, not nested in a list
model.fit(X_train, y_train)
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
# **************************************************
# [[2600]
#  [3000]
#  [3200]
#  [3600]
#  [4000]]
#
# [550000 565000 610000 680000 725000]
# **************************************************
# [[4000]
#  [3200]
#  [2600]
#  [3600]]
#
# [725000 610000 550000 680000]
# LinearRegression()

# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
new_df=df.drop("price",axis="columns")

# Training the algorithm
reg=LinearRegression()
reg.fit(new_df.values,df.price.values)

#print("training the algorithm")
# Out:
# LinearRegression()

# %%
# Predict price of a homr with area = 3300sq ft

import pandas as pd 
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
new_df=df.drop("price",axis="columns")

# Training the algorithm
reg=LinearRegression()
reg.fit(new_df.values,df.price.values)

# making predictions
print(reg.predict([[3300]]))
# Out:
# [628715.75342466]

# %%
# Capture the coeffcient from regression 
import pandas as pd 
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
new_df=df.drop("price",axis="columns")

# Training the algorithm
model=LinearRegression()
model.fit(new_df.values,df.price.values)
print("Coeffcient values :",model.coef_)
# Out:
# Coeffcient values : [135.78767123]

# %%
# Capture the intercept from regression 

import pandas as pd 
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
new_df=df.drop("price",axis="columns")

# Training the algorithm
model=LinearRegression()
model.fit(new_df.values,df.price.values)
print("Intercept values :",model.intercept_)
print()
print(dir(model))
# Out:
# Intercept values : 180616.43835616432
#
# ...

# %% [markdown]
# # In LinearRegression model  have two predefined attributes
# ## 1. coefitient => model.coef_
# ## 2. intercept  => model.intercept_
#
# # formula house_price= m*area+b
# # price = coefitient * area + intercept
# #
#
# # 135.78767123 * 2800 + 180616.43835616432 prediction we get this value by this formula
#
# #
#
#
# # In Linear Regression
# ## - LinearRegression => Name of the class
# ## - model.fit(input , output) => Predefined method in model To train the model with data
# ## - model.predict([[value]])  => to prediction with model

# %% [markdown]
# #

# %% [markdown]
# ## 12 Best fitted line
# - lets calculate the above formula
# - We can draw a line

# %%
 

import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")

plt.xlabel('area')
plt.ylabel('price')

plt.scatter(
    df.area,
    df.price,
    color='red',
    marker='*'
)

plt.show()

# %% [markdown]
# ## Lets try to draw a prediction line/smple linear regression/best fitted line

# %%
# Drawing best fitted line

import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
new_df=df.drop("price",
               axis='columns'
              )

model=LinearRegression()

model.fit(new_df.values,
          df.price.values
         )
plt.xlabel('area')
plt.ylabel('price')

plt.scatter(df.area.values,
            df.price.values,
            color='red',
            marker='*'
           )
plt.plot(df.area.values,
         model.predict([['area']].values),
         color='blue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 26
#      18 plt.ylabel('price')
#      20 plt.scatter(df.area.values,
#      21             df.price.values,
#      22             color='red',
#      23             marker='*'
#      24            )
#      25 plt.plot(df.area.values,
# ---> 26          model.predict([['area']].values),
#      27          color='blue')
#      28 plt.show()
#
# AttributeError: 'list' object has no attribute 'values'

# %%
# Drawing best fitted line

import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
new_df = df.drop("price", axis='columns')

model = LinearRegression()

model.fit(new_df.values, df.price.values)

plt.xlabel('area')
plt.ylabel('price')

plt.scatter(df.area.values,
            df.price.values,
            color='red',
            marker='*'
           )

# Fix: Use the actual area values from the dataframe for prediction
# instead of the string 'area'
plt.plot(df.area.values,
         model.predict(new_df.values),  # Use the same data format as in fit()
         color='blue')
         
plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")
df_new=df.drop("price",axis="columns")

X=df_new.values
y=df.price.values

print(X)
print(y)


model=LinearRegression()

model.fit(X,y)
print(model.predict([[2900]]))
# Out:
# [[2600]
#  [3000]
#  [3200]
#  [3600]
#  [4000]]
# [550000 565000 610000 680000 725000]
# [574400.68493151]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")

new_df=df.drop("price",axis="columns")

model=LinearRegression()

model.fit(new_df.values,df.price.values)
# Out:
# LinearRegression()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")

plt.xlabel("area")
plt.ylabel("price")

plt.scatter(df.area.values,
           df.price.values,
           marker="*",
           color="Red")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")

new_df=df.drop("price",axis="columns")

plt.xlabel("area")
plt.ylabel("price")

plt.scatter(df.area.values,
           df.price.values,
           marker="*",
           color="Red")

model=LinearRegression()
model.fit(new_df.values,df.price.values)
plt.plot(df.area.values,
        model.predict(new_df.values),
        color="Blue")
plt.show()

# %% [markdown]
# ## 13 Predicting a group of home prices
# - By using above model we can predict the group of home prices as well

# %%
import pandas as pd
df=pd.read_csv("/Users/apple/Downloads/area_price.csv")
print(df)
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
# Predicting a group of home prices 

# step 1 Importing Libraries
import pandas as pd
from sklearn.linear_model import LinearRegression

# step 2 loading Dataset
df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")


# step 3 Data preparation 
new_df=df.drop("price",axis="columns")

X=new_df.values
y=df.price.values

# Step 4 igrone right know

#s step 5 Model creating 

model=LinearRegression()

# step 6 model traing 
model.fit(X,y)

# step 7a loading the dataset 
area_df=pd.read_csv("/Users/apple/Downloads/area_price.csv")
print(area_df)
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
# Predicting a group of home prices 

# step 1 Importing Libraries
import pandas as pd
from sklearn.linear_model import LinearRegression

# step 2 loading Dataset
df = pd.read_csv("/Users/apple/Downloads/area_price_table.csv")


# step 3 Data preparation 
new_df=df.drop("price",axis="columns")

X=new_df.values
y=df.price.values

# Step 4 igrone right know

#s step 5 Model creating 

model=LinearRegression()

# step 6 model traing 
model.fit(X,y)

# step 7a loading the dataset 
area_df=pd.read_csv("/Users/apple/Downloads/area_price.csv")
print(area_df)
print()

# step 7 : prediction for group of values
result = model.predict(area_df)

# make it in a new column price
area_df["price"]=results

print(area_df)


# save csv file 
area_df.to_csv("Final_result.csv")
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100
#
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

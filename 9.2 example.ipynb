# %%
import pandas as pd
df=pd.read_csv("/Users/apple/Downloads/years_experience_salary.csv")
print(df)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
